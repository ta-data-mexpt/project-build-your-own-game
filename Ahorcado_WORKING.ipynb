# %% [markdown]
# <a href="https://colab.research.google.com/github/rshernandez10/project-build-your-own-game/blob/master/Ahorcado_WORKING.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
import os

palabras = ["COMPUTADORA" , "BALONES" , "AUDIFONO", "TECLADO", "ESCRITORIO", "GOLAZO", "NETFLIX"
"AHORCADO", "BICICLETA", "ATINADO", "TELESCOPIO"]

palabra = list(random.choice(palabras))

# %%
#print(palabra)

# %%
horca = ["          !=======|", #cuelga
         "                  |", #cabeza 
         "                  |", #brazos
         "                  |", #cuerpo
         "                  |", #piernas
         "    ______________|"] #piso

ahorcado = ["          !=======|", #cuelga
            "          :x      |", #cabeza 
            "         /|\      |", #brazos
            "          |       |", #cuerpo
            "          /\      |", #piernas
            "    _____-__-_____|"] #piso

# %%
print(horca)
print(ahorcado)
# Out:
# ['          !=======|', '                  |', '                  |', '                  |', '                  |', '    ______________|']
# ['          !=======|', '          :x      |', '         /|\\      |', '          |       |', '          /\\      |', '    _____-__-_____|']

# %%
letras_todas = []
fallos = 1

resultado = []

for i in range(len(palabra)):
    resultado.append("_")

# %%
while True:
   # os.system("cls")
    cls = lambda: os.system ("cls")
    cls()

    print ("AHORCADO")
    
    for i in range(fallos):
        print(ahorcado[i])
    for i in range(len(horca)-fallos):
        print(horca[i-fallos])

    print()

    print( "    ", end= "  ")
    for i in resultado:
          print(i, end=" ")

    print()
    print()

    if resultado == palabra:
        print("Has ganado")
        break
    
    if fallos > 5:
        print("No has adivinado, la palabra es ")
        print("Game Over")
        break
        
    while True:
        letra_usuario_sin_formato = input("Selecciona una letra: ")
        letra_usuario = letra_usuario_sin_formato.upper()
        if len(letra_usuario) != 1: #si es distinto 
             print("No es una letra. Ingresa una letra nuevamente: ")
        elif letra_usuario in letras_todas:
             print ("Letra repetida. Ingresa otra: ")
        elif  letra_usuario not in "ABCDEFGHIJKLMNÑOPQRSTUVWXYZ":
              print("No es una letra. Ingresa una letra nuevamente: ")
        else:
              letras_todas.append(letra_usuario)
              break

    for i in range(len(palabra)):
        if palabra[i] == letra_usuario:
            resultado[i] = letra_usuario

    if letra_usuario not in palabra:
        fallos += 1
  
    print()
    print()
# Out:
# AHORCADO
#           !=======|
#     ______________|
#           !=======|
#                   |
#                   |
#                   |
#
#       _ _ _ _ _ _ _
#
# Selecciona una letra: A
#
#
# AHORCADO
#           !=======|
#     ______________|
#           !=======|
#                   |
#                   |
#                   |
#
#       _ _ _ _ A _ _
#
# Selecciona una letra: C
#
#
# AHORCADO
#           !=======|
#     ______________|
#           !=======|
#                   |
#                   |
#                   |
#
#       _ _ C _ A _ _
#
# Selecciona una letra: E
#
#
# AHORCADO
#           !=======|
#     ______________|
#           !=======|
#                   |
#                   |
#                   |
#
#       _ E C _ A _ _
#
# Selecciona una letra: R
#
#
# AHORCADO
#           !=======|
#           :x      |
#                   |
#     ______________|
#           !=======|
#                   |
#
#       _ E C _ A _ _
#
# Selecciona una letra: S
#
#
# AHORCADO
#           !=======|
#           :x      |
#          /|\      |
#                   |
#                   |
#     ______________|
#
#       _ E C _ A _ _
#
# Selecciona una letra: R
# Letra repetida. Ingresa otra:
# Selecciona una letra: T
#
#
# AHORCADO
#           !=======|
#           :x      |
#          /|\      |
#                   |
#                   |
#     ______________|
#
#       T E C _ A _ _
#
# Selecciona una letra: P
#
#
# AHORCADO
#           !=======|
#           :x      |
#          /|\      |
#           |       |
#                   |
#                   |
#
#       T E C _ A _ _
#
# Selecciona una letra: L
#
#
# AHORCADO
#           !=======|
#           :x      |
#          /|\      |
#           |       |
#                   |
#                   |
#
#       T E C L A _ _
#
# Selecciona una letra: G
#
#
# AHORCADO
#           !=======|
#           :x      |
#          /|\      |
#           |       |
#           /\      |
#                   |
#
#       T E C L A _ _
#
# Selecciona una letra: N
#
#
# AHORCADO
#           !=======|
#           :x      |
#          /|\      |
#           |       |
#           /\      |
#     _____-__-_____|
#
#       T E C L A _ _
#
# No has adivinado, la palabra es
# Game Over
